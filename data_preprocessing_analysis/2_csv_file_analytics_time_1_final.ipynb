# %%
## 패키지 설치
pip install nltk konlpy pandas networkx gensim

# %%
## 코랩 한글 깨짐 현상 해결
## [방법 1]
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf


## [방법 2] 나눔고딕 설치
# !apt -qq -y install fonts-nanum > /dev/null

# import matplotlib.font_manager as fm
# fontpath = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf'
# font = fm.FontProperties(fname=fontpath, size=9)
# # fm._rebuild()

# # 그래프에 retina display 적용
# %config InlineBackend.figure_format = 'retina'

# # Colab 의 한글 폰트 설정
# plt.rc('font', family='NanumBarunGothic')

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import pandas as pd
from pandas import DataFrame

# %%
## 1. 
## [함수 정의] #################################################################
## 탐색하고자 하는 대상이 단어인가 문서인가에 따라 TF와 DF로 나뉨 ##############
## tf (term frequency) : 1개 문서 내 특정 단어 빈도
def tf(term, document):
    return document.count(term)


docs = []

## df (document frequency) : 특정 단어가 나타나는 문서의 개수
def df(term):
    df = 0
    for doc in docs:
        df += term in doc
    return df

## IDF (Inverse Document Frequency) : DF에서 역수 변환
## d : 문서, t : 단어, n : 문서 총 개수
def idf(term):
    return log(N/(df(term)+1))

## tf_idf : 많이 등장하는 단어에 패널티를 주고 단어 빈도의 스케일을 맞춰주는 방법
## 수식으로는 TF-IDF = tf*idf
def tf_idf(term, document):
    return tf(term, document) * idf(term)

# %%
####################################################################################################
## Code start ######################################################################################
####################################################################################################
from nltk.tokenize import sent_tokenize
from konlpy.corpus import kolaw
from konlpy.tag import *
from pandas import DataFrame
from math import log

import konlpy
import nltk
import pandas as pd

## 파일 읽어오기 #######################################################
## 1) 코랩에 파일 업로드
# from google.colab import files
# myfile = files.upload()

## 2) 제1기 csv 파일 읽어오기
current_work = 'time_1.csv'
table_1 = pd.read_csv(current_work)
# table_1
# type(table_1)        ## DataFrame

# %%
table_1[['등록일', '언론사', '기사제목']][:50]
# Out:
#             등록일         언론사                                          기사제목
# 0   2020.01.31.  부산일보언론사 선정         [전국 신종 코로나 현황] 확진환자 11명 정리(31일 오후 2시)
# 1   2020.01.31.        세계일보  수원 권선구 호매실동 시립금호어울림어린이집 폐쇄..원생 19명 ‘능동감시자...
# 2   2020.01.31.  경향신문언론사 선정             보스턴심포니 첫 내한공연 무산…신종 코로나바이러스 확산 우려
# 3   2020.01.31.         뉴스1               모모랜드, 신종 코로나 여파로 3월 日 팬미팅 잠정 연기
# 4   2020.01.31.   뉴시스언론사 선정                     일본서 '신종 코로나' 확진자 14명으로 늘어
# 5   2020.01.31.        연합뉴스          태국서 신종코로나 첫 '2차 감염'…"중국 방문 안 한 택시기사"
# 6   2020.01.31.        연합뉴스                 '주민 신종코로나 확진' 군산 모든 학교 졸업식 연기
# 7   2020.01.31.        이데일리                 국내 '신종코로나' 확진자 4명 추가 발생…총 11명
# 8   2020.01.30.  연합뉴스언론사 선정           또 무증상 전파? 중국서 동창회 참석 6명 신종코로나 동시 확진
# 9   2020.01.31.        연합뉴스               중국 연구진 "신종코로나, 남자가 여자보다 더 잘 걸려"
# 10  2020.01.31.   뉴스1언론사 선정              신종 코로나 확산 우려에 대학가 졸업·입학식 줄취소(종합)
# 11  2020.01.31.        연합뉴스                    이탈리아서도 신종코로나 첫 확진…20여개국 확산
# 12  2020.01.31.        서울신문                     취소·중단…신종 코로나바이러스에 공연계도 비상
# 13  2020.01.31.        연합뉴스            민주평통, 신종코로나 비상에 내달 '1만명 전체회의' 또 취소
# 14  2020.01.31.         뉴시스              부산시, 신종 코로나 19명 능동감시…1명은 자가격리 조치
# 15  2020.01.31.         뉴시스                   밀양시, 신종코로나 선별진료소 운영…대응체계 가동
# 16  2020.01.31.        연합뉴스                   신종코로나 확산에 아이돌 일정 줄취소·연기 이어져
# 17  2020.01.31.         뉴스1               '신종 코로나' 전북대, 입학식 취소…졸업식은 대폭 축소
# 18  2020.01.31.      파이낸셜뉴스          北 "南서 '신종 코로나' 넘어올라"…금강산 시설 철거 연기 통보
# 19      A5면 TOP  경향신문언론사 선정  권역별 감염병 전문병원 설치·검역인력 증원 3년째 ‘제자리’ [‘신종 코로...
# 20  2020.01.31.  부산일보언론사 선정         [전국 신종 코로나 현황] 확진환자 11명 정리(31일 오후 2시)
# 21  2020.01.31.        세계일보  수원 권선구 호매실동 시립금호어울림어린이집 폐쇄..원생 19명 ‘능동감시자...
# 22  2020.01.31.  경향신문언론사 선정             보스턴심포니 첫 내한공연 무산…신종 코로나바이러스 확산 우려
# 23  2020.01.31.         뉴스1               모모랜드, 신종 코로나 여파로 3월 日 팬미팅 잠정 연기
# 24  2020.01.31.   뉴시스언론사 선정                     일본서 '신종 코로나' 확진자 14명으로 늘어
# 25  2020.01.31.        연합뉴스          태국서 신종코로나 첫 '2차 감염'…"중국 방문 안 한 택시기사"
# 26  2020.01.31.        연합뉴스                 '주민 신종코로나 확진' 군산 모든 학교 졸업식 연기
# 27  2020.01.31.        이데일리                 국내 '신종코로나' 확진자 4명 추가 발생…총 11명
# 28  2020.01.30.  연합뉴스언론사 선정           또 무증상 전파? 중국서 동창회 참석 6명 신종코로나 동시 확진
# 29  2020.01.31.        연합뉴스               중국 연구진 "신종코로나, 남자가 여자보다 더 잘 걸려"
# 30  2020.01.31.   뉴스1언론사 선정              신종 코로나 확산 우려에 대학가 졸업·입학식 줄취소(종합)
# 31  2020.01.31.        연합뉴스                    이탈리아서도 신종코로나 첫 확진…20여개국 확산
# 32  2020.01.31.        서울신문                     취소·중단…신종 코로나바이러스에 공연계도 비상
# 33  2020.01.31.        연합뉴스            민주평통, 신종코로나 비상에 내달 '1만명 전체회의' 또 취소
# 34  2020.01.31.         뉴시스              부산시, 신종 코로나 19명 능동감시…1명은 자가격리 조치
# 35  2020.01.31.         뉴시스                   밀양시, 신종코로나 선별진료소 운영…대응체계 가동
# 36  2020.01.31.        연합뉴스                   신종코로나 확산에 아이돌 일정 줄취소·연기 이어져
# 37  2020.01.31.         뉴스1               '신종 코로나' 전북대, 입학식 취소…졸업식은 대폭 축소
# 38  2020.01.31.      파이낸셜뉴스          北 "南서 '신종 코로나' 넘어올라"…금강산 시설 철거 연기 통보
# 39      A5면 TOP  경향신문언론사 선정  권역별 감염병 전문병원 설치·검역인력 증원 3년째 ‘제자리’ [‘신종 코로...
# 40  2020.01.31.         뉴시스                 신종 코로나 감염자 중국 이외 23개국 143명 달해
# 41  2020.01.29.  연합뉴스언론사 선정            신종코로나 확산 우려에 닫힌 中하늘길…항공사, 운항 중단 확산
# 42  2020.01.31.       오마이뉴스           '신종 코로나' 공문서 형식 가짜뉴스 확산... 이재명 "엄단"
# 43  2020.01.31.        연합뉴스                    경기보건연구원, 신종코로나 검사인력 3배로 확충
# 44  2020.01.31.  국민일보언론사 선정             3번→6번→6번 가족으로 연쇄전파된 신종코로나…지역사회 패닉
# 45  2020.01.31.       오마이뉴스           [신종 코로나] 태안 '접촉자' 근무 어린이집, 결국 자체 휴원
# 46  2020.01.31.         뉴시스                신종코로나 확산, 아이돌 활동 비상···일정 연기 취소
# 47  2020.01.31.         SBS         [오늘 8뉴스] 신종 코로나 바이러스 특집 뉴스…19시 30분 시작
# 48  2020.01.31.        연합뉴스                       [일지] WHO, 신종코로나 비상사태 선포
# 49  2020.01.31.         KBS    서울광장‧노들섬 스케이트장 조기 폐장…“신종코로나바이러스 확산 우려 차...

# %%
row, col = table_1.shape

news_content = table_1['기사제목']  ## Object
#news_content

news_content_list = list(news_content)
# news_content_list

## 자료형 변환 : list -> str
# news_content_str = ' '.join(news_content_list)
news_content_str = ' '.join(map(str, news_content_list))

# %%
'''
nouns : 명사 추출
morphs : 형태소 추출
pos : 품사 부착
'''
komoran = Komoran()

## 메모리 설정
# konlpy.jvm.init_jvm(jvmpath=None, max_heap_size=1024)

## 형태소와 품사 추출 ######################################################################
# pos = komoran.pos(news_content_str)
# pos

'''
NNB: '의존 명사',
NNG: '일반 명사',
NNP: '고유 명사',
NP : '대명사',
'''

## 7분 29초 소요 ############################################################################
# Out:
# "\nNNB: '의존 명사',\nNNG: '일반 명사',\nNNP: '고유 명사',\nNP : '대명사',\n"

# %%
kopus = []
token_result = []

#############################################################################################################
## 불용어 처리 : 단어 제외하기 ########################################################################

stop_word = ['로나', '19', '째 코', '10', '20', '11', '100', '진자', '50', '위해']

for line in news_content_list:
    pos = komoran.pos(line)
    NN = [element[0] for element in pos if element[1] in ('NNP', 'NNG')]
    # print('NN >>', NN)

    NN_copy = NN[:]

    for N in NN:
      # print('N >>', N)

      if N in stop_word:
        NN_copy.remove(N)

      if len(N) == 1:
        NN_copy.remove(N)

    # print('NN : 불용어 삭제 후 >>', NN)

    token_result.append(NN_copy)
    kopus.extend(NN_copy)
        
# print('=' * 100)    
# kopus

# %%
#######################################################################################################
# docs = list(test_file['기사내용'])
docs = news_content_list

# ## 총 문서 수
# N = len(docs)
N = row

## 중복 제거한 형태소 #################################################################################
voca = list(set(kopus))
# print('중복 제거한 형태소 개수 >>', len(voca))
# voca

# print(docs)
print('docs 수 >>', len(docs))
print('N 수 >>', N)
print('형태소 개수 : voca 수 >>', len(voca))

## IDF -------------------------------------------------------------------------------
# IDE_result = []

# for t in final_voca:
#     IDE_result.append(idf(t))

# IDE_result

# idf_ = pd.DataFrame(IDE_result, index=final_voca, columns=["IDF"])
# idf_
# idf_.IDF.sort_values(ascending=False)[:30]

## tf_idf -----------------------------------------------------------------------------
TF_IDE_result = []

for word in voca:
#     print(word)
    TF_IDE_result.append(tf_idf(word, news_content_str))
    
# TF_IDE_result

tf_idf_ = pd.DataFrame(TF_IDE_result, index=voca, columns=["IDF"])
# tf_idf_

tf_idf_final = tf_idf_.sort_values(by='IDF', ascending=False)[:30]  ## 최종 30개 형태소 추출
tf_idf_final.to_csv(f'{current_work}_tf_idf.csv')
print(f'{current_work}_tf_idf.csv 파일 저장 완료!!')
# Out:
# docs 수 >> 78612
# N 수 >> 78612
# 형태소 개수 : voca 수 >> 15953
# time_1.csv_tf_idf.csv 파일 저장 완료!!

# %%
tf_idf_final
# Out:
#               IDF
# 확진   25362.327354
# 극복   14956.013474
# 지원   13093.584738
# 확산   12027.594486
# 감염   11361.190759
# 대응   11167.693477
# 신규   11081.189911
# 발생   10061.926369
# 치료    9971.004823
# 사망    9218.441604
# 방역    8683.731929
# 종합    8625.032903
# 환자    8457.394136
# 국내    8368.567301
# 치료제   7597.857212
# 지역    7412.434127
# 추가    7400.744403
# 여파    7395.082481
# 검사    7331.832327
# 백신    7224.390894
# 피해    6935.039481
# 해외    6930.540571
# 위기    6850.750057
# 정부    6848.489040
# 세계    6703.925644
# 개발    6694.059315
# 대구    6545.506386
# 한국    6471.395932
# 기부    6456.969634
# 기업    6359.518182

# %%
plt.rcParams['font.family']
# Out:
# ['NanumGothic']

# %%
############################################################################################
## koNLPy의 형태소 분석기와 NLTK의 Text 클래스를 결합하여 NLTK 기능을 사용할 수도 있다.
############################################################################################
from nltk import Text
import matplotlib.pyplot as plt
from matplotlib import pylab
# %matplotlib inline

font_path = '/usr/share/fonts/truetype/nanum/NanumGothic.ttf'

# plt.rcParams['font.family'] ='NanumGothic'
plt.rc('font', family='NanumGothic') ## 글꼴
plt.rcParams['axes.unicode_minus'] = False
plt.rcParams['figure.figsize'] = (12, 6)
plt.rcParams['font.size'] = 12
plt.xlabel('키워드')

text = Text(kopus, name="단어")

#text.vocab()
chart = text.plot(30)

# chart.savefig(f'{current_work}_chart.png')
# print('이미지 저장 완료!!')

##############################################################################################
## wordcloud #################################################################################
##############################################################################################
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# 자신의 컴퓨터 환경에 맞는 한글 폰트 경로를 설정
font_path = '/usr/share/fonts/truetype/nanum/NanumGothic.ttf'

plt.rc('font', family='NanumGothic') ## 글꼴
wc = WordCloud(width = 1000, height = 600, background_color="white", font_path=font_path)
plt.imshow(wc.generate_from_frequencies(text.vocab()))
plt.axis("off")

plt.savefig(f'{current_work}_wordcloud.png')
print('워드 클라우드 저장 완료 !!')
# Out:
# 워드 클라우드 저장 완료 !!

# %%
from gensim.models import Word2Vec
from gensim.models import KeyedVectors

## Word2Vec 훈련시키기 #####################################################################################
#type(kopus_result) ##list
# word2vec_model = Word2Vec(sentences=kopus_result, vector_size=100, window=5, min_count=5, workers=4, sg=0)
model = Word2Vec(sentences=token_result, size=100, window=5, min_count=2, workers=4, sg=1)

# %%
# 완성된 임베딩 매트릭스의 크기 확인
model.wv.vectors.shape
# Out:
# (11367, 100)

# %%
model.wv.vectors
# Out:
# array([[-0.29485062,  0.49996033, -0.07626396, ...,  0.09040827,
#         -0.36884308,  0.15358509],
#        [-0.14461984,  0.01215601, -0.35196143, ..., -0.35281843,
#         -0.39698207,  0.09384418],
#        [ 0.71569127,  0.8178729 , -0.40946433, ...,  0.51416856,
#          0.603033  ,  0.45639908],
#        ...,
#        [-0.06477582, -0.03997104, -0.029424  , ..., -0.02408524,
#          0.04218044, -0.00788941],
#        [-0.03032764, -0.01385401, -0.01267938, ..., -0.01415838,
#          0.02430383, -0.00406656],
#        [-0.17890078,  0.00587373, -0.00257063, ...,  0.04208568,
#          0.11792528,  0.01350756]], dtype=float32)

# %%
## Word2Vec ################################################################
## model.wv.most_similar: 입력한 단어에 대해서 가장 유사한 단어들 출력
############################################################################
model_result = model.wv.most_similar("코로나")
print(model_result)
# Out:
# [('대구경북', 0.5950508117675781), ('자리', 0.5869260430335999), ('기초', 0.5846017599105835), ('남부', 0.584336519241333), ('이어', 0.5823009014129639), ('7월 10일', 0.5771531462669373), ('이중', 0.5748847126960754), ('7월 30일', 0.5687723159790039), ('민간', 0.5662405490875244), ('지난', 0.566074788570404)]

# %%
model.wv.most_similar("코로나")
# Out:
# [('대구경북', 0.5950508117675781),
#  ('자리', 0.5869260430335999),
#  ('기초', 0.5846017599105835),
#  ('남부', 0.584336519241333),
#  ('이어', 0.5823009014129639),
#  ('7월 10일', 0.5771531462669373),
#  ('이중', 0.5748847126960754),
#  ('7월 30일', 0.5687723159790039),
#  ('민간', 0.5662405490875244),
#  ('지난', 0.566074788570404)]

# %%
## 코로나와 관련된 TOP 30 추출
model.wv.most_similar('코로나', topn=30)
# Out:
# [('대구경북', 0.5950508117675781),
#  ('자리', 0.5869260430335999),
#  ('기초', 0.5846017599105835),
#  ('남부', 0.584336519241333),
#  ('이어', 0.5823009014129639),
#  ('7월 10일', 0.5771531462669373),
#  ('이중', 0.5748847126960754),
#  ('7월 30일', 0.5687723159790039),
#  ('민간', 0.5662405490875244),
#  ('지난', 0.566074788570404),
#  ('참가자', 0.5633029341697693),
#  ('정리', 0.5619741678237915),
#  ('가운데', 0.5611116290092468),
#  ('일희일비', 0.5610224008560181),
#  ('재가', 0.5608706474304199),
#  ('5월 31일', 0.5569031238555908),
#  ('각지', 0.5544372797012329),
#  ('엉터리', 0.5536015629768372),
#  ('21', 0.5531676411628723),
#  ('5월 25일', 0.5525851249694824),
#  ('골든크로스', 0.5522057414054871),
#  ('분당', 0.5520172119140625),
#  ('장점', 0.5515835881233215),
#  ('가락시장', 0.551562488079071),
#  ('만리장성', 0.5513365268707275),
#  ('캘리포니아주', 0.5505578517913818),
#  ('도미노', 0.5504280924797058),
#  ('걸프', 0.5503270626068115),
#  ('시간문제', 0.5503188371658325),
#  ('설명', 0.5493086576461792)]

# %%
keyword = '위해'

table_1.기사제목[table_1.기사제목.str.contains(keyword)]
# Out:
# 216                  시흥시, 신종 코로나 대응 위해 2월 계획된 행사 전면 취소
# 232                  동구, '신종 코로나' 확산 방지 위해 각종 행사 전면 취소
# 257                         인천시, 코로나바이러스 확산방지 위해 총력 대응
# 263               대전 동구, '신종 코로나' 확산 방지 위해 각종 행사 전면 취소
# 341               대전 동구, '신종 코로나' 확산 방지 위해 각종 행사 전면 취소
#                              ...
# 78179      '비긴어게인' 코로나19로 싸우는 영웅들을 위해 소향, '널 사랑하는걸' 선곡
# 78235                      KB증권, 코로나19 극복을 위해 무지개교실 열어
# 78372                조선대, 코로나19 극복 위해 2학기 등록금 11.5% 감면
# 78538    서울시교육청, 코로나19 확산 방지 위해 수시전형 대비 특별진학상담 비대면 ...
# 78602                       KB증권, 코로나19 극복 위해 무지개교실 열어
# Name: 기사제목, Length: 1737, dtype: object

# %%
keyword = '천'

keyword_search = table_1.기사제목[table_1.기사제목.str.contains(keyword)]
print('개수 >>', len(keyword_search))
keyword_search
# Out:
# 개수 >> 3932
# 79                               인천시, '신종 코로나' 확진자 1명 그대로
# 103                       신종코로나 확진자 6명 모두 서울·경기·인천 수도권 지역
# 111                       인천 신종 코로나 격리자 이틀새 2.5배↑…18명→46명
# 115                         '신종코로나 비상'…인천 차이나타운에 관광객 발길 뚝
# 126                              인천시, '신종 코로나' 확진자 1명 그대로
#                                ...
# 78454                         [포토]코로나19로 활기 잃은 인천국제공항 출국장
# 78488                       순천 코로나 확진자 발생… 부산 157번째 접촉 추정
# 78520                  [경남소식] 3만5천개 소상공 사업장 코로나19 위기 실태조사
# 78552    [국내 코로나19] 감염 36명 늘어 총 1만4천598명.. 국내감염 해외유입보다 5배
# 78581                              '코로나19 우려'…김천전국수영대회 연기
# Name: 기사제목, Length: 3932, dtype: object

# %%
## 1. n-gram #######################################
token = list(tf_idf_final.index)
token_len = len(token)
n_gram = []

for idx, out_token in enumerate(token, 1):
    #print('out_token>>', out_token)
    
    if idx == token_len:
        break
        
    for in_token in token[idx:]:
        #print('\tin_token>>', in_token)
        n_gram.append((out_token, in_token))
        
n_gram        

# n_gram[:10]
# Out:
# [('확진', '극복'),
#  ('확진', '지원'),
#  ('확진', '확산'),
#  ('확진', '감염'),
#  ('확진', '대응'),
#  ('확진', '신규'),
#  ('확진', '발생'),
#  ('확진', '치료'),
#  ('확진', '사망'),
#  ('확진', '방역'),
#  ('확진', '종합'),
#  ('확진', '환자'),
#  ('확진', '국내'),
#  ('확진', '치료제'),
#  ('확진', '지역'),
#  ('확진', '추가'),
#  ('확진', '여파'),
#  ('확진', '검사'),
#  ('확진', '백신'),
#  ('확진', '피해'),
#  ('확진', '해외'),
#  ('확진', '위기'),
#  ('확진', '정부'),
#  ('확진', '세계'),
#  ('확진', '개발'),
#  ('확진', '대구'),
#  ('확진', '한국'),
#  ('확진', '기부'),
#  ('확진', '기업'),
#  ('극복', '지원'),
#  ('극복', '확산'),
#  ('극복', '감염'),
#  ('극복', '대응'),
#  ('극복', '신규'),
#  ('극복', '발생'),
#  ('극복', '치료'),
#  ('극복', '사망'),
#  ('극복', '방역'),
#  ('극복', '종합'),
#  ('극복', '환자'),
#  ('극복', '국내'),
#  ('극복', '치료제'),
#  ('극복', '지역'),
#  ('극복', '추가'),
#  ('극복', '여파'),
#  ('극복', '검사'),
#  ('극복', '백신'),
#  ('극복', '피해'),
#  ('극복', '해외'),
#  ('극복', '위기'),
#  ('극복', '정부'),
#  ('극복', '세계'),
#  ('극복', '개발'),
#  ('극복', '대구'),
#  ('극복', '한국'),
#  ('극복', '기부'),
#  ('극복', '기업'),
#  ('지원', '확산'),
#  ('지원', '감염'),
#  ('지원', '대응'),
#  ('지원', '신규'),
#  ('지원', '발생'),
#  ('지원', '치료'),
#  ('지원', '사망'),
#  ('지원', '방역'),
#  ('지원', '종합'),
#  ('지원', '환자'),
#  ('지원', '국내'),
#  ('지원', '치료제'),
#  ('지원', '지역'),
#  ('지원', '추가'),
#  ('지원', '여파'),
#  ('지원', '검사'),
#  ('지원', '백신'),
#  ('지원', '피해'),
#  ('지원', '해외'),
#  ('지원', '위기'),
#  ('지원', '정부'),
#  ('지원', '세계'),
#  ('지원', '개발'),
#  ('지원', '대구'),
#  ('지원', '한국'),
#  ('지원', '기부'),
#  ('지원', '기업'),
#  ('확산', '감염'),
#  ('확산', '대응'),
#  ('확산', '신규'),
#  ('확산', '발생'),
#  ('확산', '치료'),
#  ('확산', '사망'),
#  ('확산', '방역'),
#  ('확산', '종합'),
#  ('확산', '환자'),
#  ('확산', '국내'),
#  ('확산', '치료제'),
#  ('확산', '지역'),
#  ('확산', '추가'),
#  ('확산', '여파'),
#  ('확산', '검사'),
#  ('확산', '백신'),
#  ('확산', '피해'),
#  ('확산', '해외'),
#  ('확산', '위기'),
#  ('확산', '정부'),
#  ('확산', '세계'),
#  ('확산', '개발'),
#  ('확산', '대구'),
#  ('확산', '한국'),
#  ('확산', '기부'),
#  ('확산', '기업'),
#  ('감염', '대응'),
#  ('감염', '신규'),
#  ('감염', '발생'),
#  ('감염', '치료'),
#  ('감염', '사망'),
#  ('감염', '방역'),
#  ('감염', '종합'),
#  ('감염', '환자'),
#  ('감염', '국내'),
#  ('감염', '치료제'),
#  ('감염', '지역'),
#  ('감염', '추가'),
#  ('감염', '여파'),
#  ('감염', '검사'),
#  ('감염', '백신'),
#  ('감염', '피해'),
#  ('감염', '해외'),
#  ('감염', '위기'),
#  ('감염', '정부'),
#  ('감염', '세계'),
#  ('감염', '개발'),
#  ('감염', '대구'),
#  ('감염', '한국'),
#  ('감염', '기부'),
#  ('감염', '기업'),
#  ('대응', '신규'),
#  ('대응', '발생'),
#  ('대응', '치료'),
#  ('대응', '사망'),
#  ('대응', '방역'),
#  ('대응', '종합'),
#  ('대응', '환자'),
#  ('대응', '국내'),
#  ('대응', '치료제'),
#  ('대응', '지역'),
#  ('대응', '추가'),
#  ('대응', '여파'),
#  ('대응', '검사'),
#  ('대응', '백신'),
#  ('대응', '피해'),
#  ('대응', '해외'),
#  ('대응', '위기'),
#  ('대응', '정부'),
#  ('대응', '세계'),
#  ('대응', '개발'),
#  ('대응', '대구'),
#  ('대응', '한국'),
#  ('대응', '기부'),
#  ('대응', '기업'),
#  ('신규', '발생'),
#  ('신규', '치료'),
#  ('신규', '사망'),
#  ('신규', '방역'),
#  ('신규', '종합'),
#  ('신규', '환자'),
#  ('신규', '국내'),
#  ('신규', '치료제'),
#  ('신규', '지역'),
#  ('신규', '추가'),
#  ('신규', '여파'),
#  ('신규', '검사'),
#  ('신규', '백신'),
#  ('신규', '피해'),
#  ('신규', '해외'),
#  ('신규', '위기'),
#  ('신규', '정부'),
#  ('신규', '세계'),
#  ('신규', '개발'),
#  ('신규', '대구'),
#  ('신규', '한국'),
#  ('신규', '기부'),
#  ('신규', '기업'),
#  ('발생', '치료'),
#  ('발생', '사망'),
#  ('발생', '방역'),
#  ('발생', '종합'),
#  ('발생', '환자'),
#  ('발생', '국내'),
#  ('발생', '치료제'),
#  ('발생', '지역'),
#  ('발생', '추가'),
#  ('발생', '여파'),
#  ('발생', '검사'),
#  ('발생', '백신'),
#  ('발생', '피해'),
#  ('발생', '해외'),
#  ('발생', '위기'),
#  ('발생', '정부'),
#  ('발생', '세계'),
#  ('발생', '개발'),
#  ('발생', '대구'),
#  ('발생', '한국'),
#  ('발생', '기부'),
#  ('발생', '기업'),
#  ('치료', '사망'),
#  ('치료', '방역'),
#  ('치료', '종합'),
#  ('치료', '환자'),
#  ('치료', '국내'),
#  ('치료', '치료제'),
#  ('치료', '지역'),
#  ('치료', '추가'),
#  ('치료', '여파'),
#  ('치료', '검사'),
#  ('치료', '백신'),
#  ('치료', '피해'),
#  ('치료', '해외'),
#  ('치료', '위기'),
#  ('치료', '정부'),
#  ('치료', '세계'),
#  ('치료', '개발'),
#  ('치료', '대구'),
#  ('치료', '한국'),
#  ('치료', '기부'),
#  ('치료', '기업'),
#  ('사망', '방역'),
#  ('사망', '종합'),
#  ('사망', '환자'),
#  ('사망', '국내'),
#  ('사망', '치료제'),
#  ('사망', '지역'),
#  ('사망', '추가'),
#  ('사망', '여파'),
#  ('사망', '검사'),
#  ('사망', '백신'),
#  ('사망', '피해'),
#  ('사망', '해외'),
#  ('사망', '위기'),
#  ('사망', '정부'),
#  ('사망', '세계'),
#  ('사망', '개발'),
#  ('사망', '대구'),
#  ('사망', '한국'),
#  ('사망', '기부'),
#  ('사망', '기업'),
#  ('방역', '종합'),
#  ('방역', '환자'),
#  ('방역', '국내'),
#  ('방역', '치료제'),
#  ('방역', '지역'),
#  ('방역', '추가'),
#  ('방역', '여파'),
#  ('방역', '검사'),
#  ('방역', '백신'),
#  ('방역', '피해'),
#  ('방역', '해외'),
#  ('방역', '위기'),
#  ('방역', '정부'),
#  ('방역', '세계'),
#  ('방역', '개발'),
#  ('방역', '대구'),
#  ('방역', '한국'),
#  ('방역', '기부'),
#  ('방역', '기업'),
#  ('종합', '환자'),
#  ('종합', '국내'),
#  ('종합', '치료제'),
#  ('종합', '지역'),
#  ('종합', '추가'),
#  ('종합', '여파'),
#  ('종합', '검사'),
#  ('종합', '백신'),
#  ('종합', '피해'),
#  ('종합', '해외'),
#  ('종합', '위기'),
#  ('종합', '정부'),
#  ('종합', '세계'),
#  ('종합', '개발'),
#  ('종합', '대구'),
#  ('종합', '한국'),
#  ('종합', '기부'),
#  ('종합', '기업'),
#  ('환자', '국내'),
#  ('환자', '치료제'),
#  ('환자', '지역'),
#  ('환자', '추가'),
#  ('환자', '여파'),
#  ('환자', '검사'),
#  ('환자', '백신'),
#  ('환자', '피해'),
#  ('환자', '해외'),
#  ('환자', '위기'),
#  ('환자', '정부'),
#  ('환자', '세계'),
#  ('환자', '개발'),
#  ('환자', '대구'),
#  ('환자', '한국'),
#  ('환자', '기부'),
#  ('환자', '기업'),
#  ('국내', '치료제'),
#  ('국내', '지역'),
#  ('국내', '추가'),
#  ('국내', '여파'),
#  ('국내', '검사'),
#  ('국내', '백신'),
#  ('국내', '피해'),
#  ('국내', '해외'),
#  ('국내', '위기'),
#  ('국내', '정부'),
#  ('국내', '세계'),
#  ('국내', '개발'),
#  ('국내', '대구'),
#  ('국내', '한국'),
#  ('국내', '기부'),
#  ('국내', '기업'),
#  ('치료제', '지역'),
#  ('치료제', '추가'),
#  ('치료제', '여파'),
#  ('치료제', '검사'),
#  ('치료제', '백신'),
#  ('치료제', '피해'),
#  ('치료제', '해외'),
#  ('치료제', '위기'),
#  ('치료제', '정부'),
#  ('치료제', '세계'),
#  ('치료제', '개발'),
#  ('치료제', '대구'),
#  ('치료제', '한국'),
#  ('치료제', '기부'),
#  ('치료제', '기업'),
#  ('지역', '추가'),
#  ('지역', '여파'),
#  ('지역', '검사'),
#  ('지역', '백신'),
#  ('지역', '피해'),
#  ('지역', '해외'),
#  ('지역', '위기'),
#  ('지역', '정부'),
#  ('지역', '세계'),
#  ('지역', '개발'),
#  ('지역', '대구'),
#  ('지역', '한국'),
#  ('지역', '기부'),
#  ('지역', '기업'),
#  ('추가', '여파'),
#  ('추가', '검사'),
#  ('추가', '백신'),
#  ('추가', '피해'),
#  ('추가', '해외'),
#  ('추가', '위기'),
#  ('추가', '정부'),
#  ('추가', '세계'),
#  ('추가', '개발'),
#  ('추가', '대구'),
#  ('추가', '한국'),
#  ('추가', '기부'),
#  ('추가', '기업'),
#  ('여파', '검사'),
#  ('여파', '백신'),
#  ('여파', '피해'),
#  ('여파', '해외'),
#  ('여파', '위기'),
#  ('여파', '정부'),
#  ('여파', '세계'),
#  ('여파', '개발'),
#  ('여파', '대구'),
#  ('여파', '한국'),
#  ('여파', '기부'),
#  ('여파', '기업'),
#  ('검사', '백신'),
#  ('검사', '피해'),
#  ('검사', '해외'),
#  ('검사', '위기'),
#  ('검사', '정부'),
#  ('검사', '세계'),
#  ('검사', '개발'),
#  ('검사', '대구'),
#  ('검사', '한국'),
#  ('검사', '기부'),
#  ('검사', '기업'),
#  ('백신', '피해'),
#  ('백신', '해외'),
#  ('백신', '위기'),
#  ('백신', '정부'),
#  ('백신', '세계'),
#  ('백신', '개발'),
#  ('백신', '대구'),
#  ('백신', '한국'),
#  ('백신', '기부'),
#  ('백신', '기업'),
#  ('피해', '해외'),
#  ('피해', '위기'),
#  ('피해', '정부'),
#  ('피해', '세계'),
#  ('피해', '개발'),
#  ('피해', '대구'),
#  ('피해', '한국'),
#  ('피해', '기부'),
#  ('피해', '기업'),
#  ('해외', '위기'),
#  ('해외', '정부'),
#  ('해외', '세계'),
#  ('해외', '개발'),
#  ('해외', '대구'),
#  ('해외', '한국'),
#  ('해외', '기부'),
#  ('해외', '기업'),
#  ('위기', '정부'),
#  ('위기', '세계'),
#  ('위기', '개발'),
#  ('위기', '대구'),
#  ('위기', '한국'),
#  ('위기', '기부'),
#  ('위기', '기업'),
#  ('정부', '세계'),
#  ('정부', '개발'),
#  ('정부', '대구'),
#  ('정부', '한국'),
#  ('정부', '기부'),
#  ('정부', '기업'),
#  ('세계', '개발'),
#  ('세계', '대구'),
#  ('세계', '한국'),
#  ('세계', '기부'),
#  ('세계', '기업'),
#  ('개발', '대구'),
#  ('개발', '한국'),
#  ('개발', '기부'),
#  ('개발', '기업'),
#  ('대구', '한국'),
#  ('대구', '기부'),
#  ('대구', '기업'),
#  ('한국', '기부'),
#  ('한국', '기업'),
#  ('기부', '기업')]

# %%
## 2. 어휘 동시 출현 빈도의 계수화 #######################################
co_occurrence = {}

for token_element in token_result:
    for n in n_gram:
        compare = set(token_element) & set(n)
        if len(compare) == 2:
            co_occurrence[n] = co_occurrence.get(n, 0) + 1
            
co_occurrence
# Out:
# {('감염', '개발'): 40,
#  ('감염', '검사'): 49,
#  ('감염', '국내'): 122,
#  ('감염', '기부'): 3,
#  ('감염', '기업'): 7,
#  ('감염', '대구'): 46,
#  ('감염', '대응'): 16,
#  ('감염', '발생'): 175,
#  ('감염', '방역'): 74,
#  ('감염', '백신'): 14,
#  ('감염', '사망'): 100,
#  ('감염', '세계'): 36,
#  ('감염', '신규'): 429,
#  ('감염', '여파'): 26,
#  ('감염', '위기'): 9,
#  ('감염', '정부'): 23,
#  ('감염', '종합'): 180,
#  ('감염', '지역'): 327,
#  ('감염', '추가'): 120,
#  ('감염', '치료'): 13,
#  ('감염', '치료제'): 10,
#  ('감염', '피해'): 7,
#  ('감염', '한국'): 21,
#  ('감염', '해외'): 119,
#  ('감염', '환자'): 83,
#  ('개발', '기부'): 14,
#  ('개발', '기업'): 39,
#  ('개발', '대구'): 8,
#  ('개발', '한국'): 9,
#  ('검사', '개발'): 18,
#  ('검사', '기부'): 1,
#  ('검사', '기업'): 2,
#  ('검사', '대구'): 30,
#  ('검사', '백신'): 6,
#  ('검사', '세계'): 12,
#  ('검사', '위기'): 1,
#  ('검사', '정부'): 43,
#  ('검사', '피해'): 1,
#  ('검사', '한국'): 45,
#  ('검사', '해외'): 13,
#  ('국내', '개발'): 44,
#  ('국내', '검사'): 21,
#  ('국내', '기업'): 49,
#  ('국내', '대구'): 89,
#  ('국내', '백신'): 92,
#  ('국내', '세계'): 21,
#  ('국내', '여파'): 34,
#  ('국내', '위기'): 31,
#  ('국내', '정부'): 13,
#  ('국내', '지역'): 91,
#  ('국내', '추가'): 111,
#  ('국내', '치료제'): 159,
#  ('국내', '피해'): 2,
#  ('국내', '한국'): 31,
#  ('국내', '해외'): 272,
#  ('극복', '감염'): 6,
#  ('극복', '개발'): 16,
#  ('극복', '검사'): 1,
#  ('극복', '국내'): 9,
#  ('극복', '기부'): 566,
#  ('극복', '기업'): 77,
#  ('극복', '대구'): 105,
#  ('극복', '대응'): 38,
#  ('극복', '방역'): 74,
#  ('극복', '백신'): 13,
#  ('극복', '세계'): 37,
#  ('극복', '신규'): 4,
#  ('극복', '여파'): 5,
#  ('극복', '위기'): 643,
#  ('극복', '정부'): 47,
#  ('극복', '종합'): 43,
#  ('극복', '지역'): 143,
#  ('극복', '지원'): 497,
#  ('극복', '추가'): 40,
#  ('극복', '치료'): 1,
#  ('극복', '치료제'): 8,
#  ('극복', '피해'): 82,
#  ('극복', '한국'): 66,
#  ('극복', '해외'): 34,
#  ('극복', '확산'): 19,
#  ('기부', '기업'): 15,
#  ('대구', '기부'): 43,
#  ('대구', '기업'): 15,
#  ('대구', '한국'): 5,
#  ('대응', '개발'): 31,
#  ('대응', '검사'): 18,
#  ('대응', '국내'): 19,
#  ('대응', '기부'): 12,
#  ('대응', '기업'): 39,
#  ('대응', '대구'): 49,
#  ('대응', '발생'): 32,
#  ('대응', '방역'): 121,
#  ('대응', '백신'): 23,
#  ('대응', '사망'): 11,
#  ('대응', '세계'): 67,
#  ('대응', '신규'): 11,
#  ('대응', '여파'): 3,
#  ('대응', '위기'): 87,
#  ('대응', '정부'): 204,
#  ('대응', '종합'): 56,
#  ('대응', '지역'): 90,
#  ('대응', '추가'): 26,
#  ('대응', '치료'): 10,
#  ('대응', '치료제'): 9,
#  ('대응', '피해'): 16,
#  ('대응', '한국'): 180,
#  ('대응', '해외'): 32,
#  ('대응', '환자'): 24,
#  ('발생', '개발'): 1,
#  ('발생', '검사'): 32,
#  ('발생', '국내'): 523,
#  ('발생', '기업'): 3,
#  ('발생', '대구'): 83,
#  ('발생', '방역'): 52,
#  ('발생', '백신'): 2,
#  ('발생', '사망'): 18,
#  ('발생', '세계'): 16,
#  ('발생', '여파'): 6,
#  ('발생', '위기'): 24,
#  ('발생', '정부'): 13,
#  ('발생', '종합'): 139,
#  ('발생', '지역'): 546,
#  ('발생', '추가'): 356,
#  ('발생', '치료'): 15,
#  ('발생', '치료제'): 4,
#  ('발생', '피해'): 4,
#  ('발생', '한국'): 28,
#  ('발생', '해외'): 468,
#  ('발생', '환자'): 340,
#  ('방역', '개발'): 45,
#  ('방역', '검사'): 29,
#  ('방역', '국내'): 29,
#  ('방역', '기부'): 17,
#  ('방역', '기업'): 8,
#  ('방역', '대구'): 43,
#  ('방역', '백신'): 41,
#  ('방역', '세계'): 25,
#  ('방역', '여파'): 10,
#  ('방역', '위기'): 24,
#  ('방역', '정부'): 74,
#  ('방역', '종합'): 66,
#  ('방역', '지역'): 46,
#  ('방역', '추가'): 25,
#  ('방역', '치료제'): 32,
#  ('방역', '피해'): 8,
#  ('방역', '한국'): 35,
#  ('방역', '해외'): 35,
#  ('방역', '환자'): 44,
#  ('백신', '개발'): 865,
#  ('백신', '기부'): 12,
#  ('백신', '기업'): 29,
#  ('백신', '세계'): 57,
#  ('백신', '정부'): 143,
#  ('백신', '피해'): 1,
#  ('백신', '한국'): 20,
#  ('백신', '해외'): 7,
#  ('사망', '검사'): 16,
#  ('사망', '국내'): 83,
#  ('사망', '대구'): 111,
#  ('사망', '방역'): 6,
#  ('사망', '세계'): 47,
#  ('사망', '위기'): 1,
#  ('사망', '정부'): 7,
#  ('사망', '종합'): 80,
#  ('사망', '지역'): 5,
#  ('사망', '추가'): 36,
#  ('사망', '치료제'): 1,
#  ('사망', '피해'): 1,
#  ('사망', '한국'): 18,
#  ('사망', '해외'): 6,
#  ('사망', '환자'): 78,
#  ('세계', '개발'): 22,
#  ('세계', '기부'): 3,
#  ('세계', '기업'): 9,
#  ('세계', '대구'): 2,
#  ('세계', '한국'): 60,
#  ('신규', '개발'): 4,
#  ('신규', '검사'): 11,
#  ('신규', '국내'): 386,
#  ('신규', '기업'): 8,
#  ('신규', '대구'): 116,
#  ('신규', '발생'): 699,
#  ('신규', '방역'): 26,
#  ('신규', '백신'): 2,
#  ('신규', '사망'): 103,
#  ('신규', '세계'): 19,
#  ('신규', '여파'): 22,
#  ('신규', '위기'): 8,
#  ('신규', '정부'): 17,
#  ('신규', '종합'): 235,
#  ('신규', '지역'): 595,
#  ('신규', '추가'): 66,
#  ('신규', '치료'): 6,
#  ('신규', '치료제'): 2,
#  ('신규', '피해'): 3,
#  ('신규', '한국'): 5,
#  ('신규', '해외'): 623,
#  ('신규', '환자'): 228,
#  ('여파', '검사'): 5,
#  ('여파', '기부'): 2,
#  ('여파', '기업'): 30,
#  ('여파', '대구'): 12,
#  ('여파', '백신'): 2,
#  ('여파', '세계'): 50,
#  ('여파', '위기'): 18,
#  ('여파', '정부'): 7,
#  ('여파', '피해'): 5,
#  ('여파', '한국'): 33,
#  ('여파', '해외'): 20,
#  ('위기', '개발'): 4,
#  ('위기', '기부'): 46,
#  ('위기', '기업'): 65,
#  ('위기', '대구'): 23,
#  ('위기', '세계'): 34,
#  ('위기', '정부'): 37,
#  ('위기', '한국'): 15,
#  ('정부', '개발'): 117,
#  ('정부', '기부'): 12,
#  ('정부', '기업'): 15,
#  ('정부', '대구'): 12,
#  ('정부', '세계'): 20,
#  ('정부', '한국'): 32,
#  ('종합', '개발'): 22,
#  ('종합', '검사'): 84,
#  ('종합', '국내'): 89,
#  ('종합', '기부'): 10,
#  ('종합', '기업'): 15,
#  ('종합', '대구'): 71,
#  ('종합', '백신'): 41,
#  ('종합', '세계'): 45,
#  ('종합', '여파'): 46,
#  ('종합', '위기'): 49,
#  ('종합', '정부'): 57,
#  ('종합', '지역'): 84,
#  ('종합', '추가'): 131,
#  ('종합', '치료제'): 30,
#  ('종합', '피해'): 23,
#  ('종합', '한국'): 36,
#  ('종합', '해외'): 84,
#  ('종합', '환자'): 120,
#  ('지역', '개발'): 1,
#  ('지역', '검사'): 12,
#  ('지역', '기부'): 16,
#  ('지역', '기업'): 16,
#  ('지역', '대구'): 119,
#  ('지역', '백신'): 2,
#  ('지역', '세계'): 6,
#  ('지역', '여파'): 19,
#  ('지역', '위기'): 31,
#  ('지역', '정부'): 12,
#  ('지역', '추가'): 71,
#  ('지역', '피해'): 53,
#  ('지역', '한국'): 7,
#  ('지역', '해외'): 429,
#  ('지원', '감염'): 32,
#  ('지원', '개발'): 90,
#  ('지원', '검사'): 26,
#  ('지원', '국내'): 19,
#  ('지원', '기부'): 59,
#  ('지원', '기업'): 215,
#  ('지원', '대구'): 80,
#  ('지원', '대응'): 274,
#  ('지원', '발생'): 6,
#  ('지원', '방역'): 165,
#  ('지원', '백신'): 79,
#  ('지원', '사망'): 4,
#  ('지원', '세계'): 16,
#  ('지원', '신규'): 5,
#  ('지원', '여파'): 29,
#  ('지원', '위기'): 159,
#  ('지원', '정부'): 253,
#  ('지원', '종합'): 52,
#  ('지원', '지역'): 144,
#  ('지원', '추가'): 130,
#  ('지원', '치료'): 8,
#  ('지원', '치료제'): 80,
#  ('지원', '피해'): 757,
#  ('지원', '한국'): 34,
#  ('지원', '해외'): 23,
#  ('지원', '확산'): 67,
#  ('지원', '환자'): 17,
#  ('추가', '개발'): 5,
#  ('추가', '검사'): 47,
#  ('추가', '기부'): 5,
#  ('추가', '기업'): 7,
#  ('추가', '대구'): 80,
#  ('추가', '백신'): 11,
#  ('추가', '세계'): 4,
#  ('추가', '여파'): 11,
#  ('추가', '위기'): 5,
#  ('추가', '정부'): 31,
#  ('추가', '피해'): 56,
#  ('추가', '한국'): 6,
#  ('추가', '해외'): 87,
#  ('치료', '개발'): 15,
#  ('치료', '검사'): 2,
#  ('치료', '국내'): 23,
#  ('치료', '기부'): 5,
#  ('치료', '기업'): 1,
#  ('치료', '대구'): 19,
#  ('치료', '방역'): 32,
#  ('치료', '백신'): 6,
#  ('치료', '사망'): 24,
#  ('치료', '세계'): 9,
#  ('치료', '정부'): 20,
#  ('치료', '종합'): 19,
#  ('치료', '지역'): 8,
#  ('치료', '추가'): 15,
#  ('치료', '치료제'): 45,
#  ('치료', '한국'): 1,
#  ('치료', '해외'): 1,
#  ('치료', '환자'): 144,
#  ('치료제', '개발'): 688,
#  ('치료제', '기부'): 6,
#  ('치료제', '기업'): 14,
#  ('치료제', '대구'): 1,
#  ('치료제', '백신'): 500,
#  ('치료제', '세계'): 13,
#  ('치료제', '정부'): 153,
#  ('치료제', '추가'): 4,
#  ('치료제', '한국'): 19,
#  ('치료제', '해외'): 4,
#  ('피해', '개발'): 1,
#  ('피해', '기부'): 97,
#  ('피해', '기업'): 240,
#  ('피해', '대구'): 46,
#  ('피해', '세계'): 12,
#  ('피해', '위기'): 11,
#  ('피해', '정부'): 42,
#  ('피해', '한국'): 9,
#  ('피해', '해외'): 3,
#  ('한국', '기부'): 22,
#  ('한국', '기업'): 15,
#  ('해외', '개발'): 7,
#  ('해외', '기부'): 17,
#  ('해외', '기업'): 27,
#  ('해외', '대구'): 27,
#  ('해외', '세계'): 8,
#  ('해외', '위기'): 5,
#  ('해외', '정부'): 19,
#  ('해외', '한국'): 28,
#  ('확산', '감염'): 256,
#  ('확산', '개발'): 30,
#  ('확산', '검사'): 25,
#  ('확산', '국내'): 71,
#  ('확산', '기부'): 89,
#  ('확산', '기업'): 21,
#  ('확산', '대구'): 33,
#  ('확산', '대응'): 73,
#  ('확산', '발생'): 65,
#  ('확산', '방역'): 149,
#  ('확산', '백신'): 7,
#  ('확산', '사망'): 16,
#  ('확산', '세계'): 108,
#  ('확산', '신규'): 172,
#  ('확산', '여파'): 66,
#  ('확산', '위기'): 31,
#  ('확산', '정부'): 71,
#  ('확산', '종합'): 171,
#  ('확산', '지역'): 153,
#  ('확산', '추가'): 43,
#  ('확산', '치료'): 4,
#  ('확산', '치료제'): 6,
#  ('확산', '피해'): 22,
#  ('확산', '한국'): 56,
#  ('확산', '해외'): 33,
#  ('확산', '환자'): 42,
#  ('확진', '감염'): 986,
#  ('확진', '개발'): 15,
#  ('확진', '검사'): 292,
#  ('확진', '국내'): 1156,
#  ('확진', '극복'): 4,
#  ('확진', '기부'): 10,
#  ('확진', '기업'): 4,
#  ('확진', '대구'): 423,
#  ('확진', '대응'): 53,
#  ('확진', '발생'): 2321,
#  ('확진', '방역'): 212,
#  ('확진', '백신'): 14,
#  ('확진', '사망'): 340,
#  ('확진', '세계'): 364,
#  ('확진', '신규'): 3174,
#  ('확진', '여파'): 40,
#  ('확진', '위기'): 44,
#  ('확진', '정부'): 64,
#  ('확진', '종합'): 805,
#  ('확진', '지역'): 852,
#  ('확진', '지원'): 40,
#  ('확진', '추가'): 1366,
#  ('확진', '치료'): 87,
#  ('확진', '치료제'): 2,
#  ('확진', '피해'): 28,
#  ('확진', '한국'): 96,
#  ('확진', '해외'): 1044,
#  ('확진', '확산'): 394,
#  ('확진', '환자'): 544,
#  ('환자', '개발'): 13,
#  ('환자', '검사'): 53,
#  ('환자', '국내'): 267,
#  ('환자', '기부'): 1,
#  ('환자', '대구'): 76,
#  ('환자', '백신'): 7,
#  ('환자', '세계'): 27,
#  ('환자', '여파'): 3,
#  ('환자', '위기'): 10,
#  ('환자', '정부'): 26,
#  ('환자', '지역'): 60,
#  ('환자', '추가'): 143,
#  ('환자', '치료제'): 38,
#  ('환자', '한국'): 35,
#  ('환자', '해외'): 62}

# %%
## 2. 어휘 동시 출현 빈도의 계수화 #######################################
co_occurrence = {}

for token_element in token_result:
    for n in n_gram:
        compare = set(token_element) & set(n)
        if len(compare) == 2:
            co_occurrence[n] = co_occurrence.get(n, 0) + 1
            
co_occurrence
# Out:
# {('감염', '개발'): 40,
#  ('감염', '검사'): 49,
#  ('감염', '국내'): 122,
#  ('감염', '기부'): 3,
#  ('감염', '기업'): 7,
#  ('감염', '대구'): 46,
#  ('감염', '대응'): 16,
#  ('감염', '발생'): 175,
#  ('감염', '방역'): 74,
#  ('감염', '백신'): 14,
#  ('감염', '사망'): 100,
#  ('감염', '세계'): 36,
#  ('감염', '신규'): 429,
#  ('감염', '여파'): 26,
#  ('감염', '위기'): 9,
#  ('감염', '정부'): 23,
#  ('감염', '종합'): 180,
#  ('감염', '지역'): 327,
#  ('감염', '추가'): 120,
#  ('감염', '치료'): 13,
#  ('감염', '치료제'): 10,
#  ('감염', '피해'): 7,
#  ('감염', '한국'): 21,
#  ('감염', '해외'): 119,
#  ('감염', '환자'): 83,
#  ('개발', '기부'): 14,
#  ('개발', '기업'): 39,
#  ('개발', '대구'): 8,
#  ('개발', '한국'): 9,
#  ('검사', '개발'): 18,
#  ('검사', '기부'): 1,
#  ('검사', '기업'): 2,
#  ('검사', '대구'): 30,
#  ('검사', '백신'): 6,
#  ('검사', '세계'): 12,
#  ('검사', '위기'): 1,
#  ('검사', '정부'): 43,
#  ('검사', '피해'): 1,
#  ('검사', '한국'): 45,
#  ('검사', '해외'): 13,
#  ('국내', '개발'): 44,
#  ('국내', '검사'): 21,
#  ('국내', '기업'): 49,
#  ('국내', '대구'): 89,
#  ('국내', '백신'): 92,
#  ('국내', '세계'): 21,
#  ('국내', '여파'): 34,
#  ('국내', '위기'): 31,
#  ('국내', '정부'): 13,
#  ('국내', '지역'): 91,
#  ('국내', '추가'): 111,
#  ('국내', '치료제'): 159,
#  ('국내', '피해'): 2,
#  ('국내', '한국'): 31,
#  ('국내', '해외'): 272,
#  ('극복', '감염'): 6,
#  ('극복', '개발'): 16,
#  ('극복', '검사'): 1,
#  ('극복', '국내'): 9,
#  ('극복', '기부'): 566,
#  ('극복', '기업'): 77,
#  ('극복', '대구'): 105,
#  ('극복', '대응'): 38,
#  ('극복', '방역'): 74,
#  ('극복', '백신'): 13,
#  ('극복', '세계'): 37,
#  ('극복', '신규'): 4,
#  ('극복', '여파'): 5,
#  ('극복', '위기'): 643,
#  ('극복', '정부'): 47,
#  ('극복', '종합'): 43,
#  ('극복', '지역'): 143,
#  ('극복', '지원'): 497,
#  ('극복', '추가'): 40,
#  ('극복', '치료'): 1,
#  ('극복', '치료제'): 8,
#  ('극복', '피해'): 82,
#  ('극복', '한국'): 66,
#  ('극복', '해외'): 34,
#  ('극복', '확산'): 19,
#  ('기부', '기업'): 15,
#  ('대구', '기부'): 43,
#  ('대구', '기업'): 15,
#  ('대구', '한국'): 5,
#  ('대응', '개발'): 31,
#  ('대응', '검사'): 18,
#  ('대응', '국내'): 19,
#  ('대응', '기부'): 12,
#  ('대응', '기업'): 39,
#  ('대응', '대구'): 49,
#  ('대응', '발생'): 32,
#  ('대응', '방역'): 121,
#  ('대응', '백신'): 23,
#  ('대응', '사망'): 11,
#  ('대응', '세계'): 67,
#  ('대응', '신규'): 11,
#  ('대응', '여파'): 3,
#  ('대응', '위기'): 87,
#  ('대응', '정부'): 204,
#  ('대응', '종합'): 56,
#  ('대응', '지역'): 90,
#  ('대응', '추가'): 26,
#  ('대응', '치료'): 10,
#  ('대응', '치료제'): 9,
#  ('대응', '피해'): 16,
#  ('대응', '한국'): 180,
#  ('대응', '해외'): 32,
#  ('대응', '환자'): 24,
#  ('발생', '개발'): 1,
#  ('발생', '검사'): 32,
#  ('발생', '국내'): 523,
#  ('발생', '기업'): 3,
#  ('발생', '대구'): 83,
#  ('발생', '방역'): 52,
#  ('발생', '백신'): 2,
#  ('발생', '사망'): 18,
#  ('발생', '세계'): 16,
#  ('발생', '여파'): 6,
#  ('발생', '위기'): 24,
#  ('발생', '정부'): 13,
#  ('발생', '종합'): 139,
#  ('발생', '지역'): 546,
#  ('발생', '추가'): 356,
#  ('발생', '치료'): 15,
#  ('발생', '치료제'): 4,
#  ('발생', '피해'): 4,
#  ('발생', '한국'): 28,
#  ('발생', '해외'): 468,
#  ('발생', '환자'): 340,
#  ('방역', '개발'): 45,
#  ('방역', '검사'): 29,
#  ('방역', '국내'): 29,
#  ('방역', '기부'): 17,
#  ('방역', '기업'): 8,
#  ('방역', '대구'): 43,
#  ('방역', '백신'): 41,
#  ('방역', '세계'): 25,
#  ('방역', '여파'): 10,
#  ('방역', '위기'): 24,
#  ('방역', '정부'): 74,
#  ('방역', '종합'): 66,
#  ('방역', '지역'): 46,
#  ('방역', '추가'): 25,
#  ('방역', '치료제'): 32,
#  ('방역', '피해'): 8,
#  ('방역', '한국'): 35,
#  ('방역', '해외'): 35,
#  ('방역', '환자'): 44,
#  ('백신', '개발'): 865,
#  ('백신', '기부'): 12,
#  ('백신', '기업'): 29,
#  ('백신', '세계'): 57,
#  ('백신', '정부'): 143,
#  ('백신', '피해'): 1,
#  ('백신', '한국'): 20,
#  ('백신', '해외'): 7,
#  ('사망', '검사'): 16,
#  ('사망', '국내'): 83,
#  ('사망', '대구'): 111,
#  ('사망', '방역'): 6,
#  ('사망', '세계'): 47,
#  ('사망', '위기'): 1,
#  ('사망', '정부'): 7,
#  ('사망', '종합'): 80,
#  ('사망', '지역'): 5,
#  ('사망', '추가'): 36,
#  ('사망', '치료제'): 1,
#  ('사망', '피해'): 1,
#  ('사망', '한국'): 18,
#  ('사망', '해외'): 6,
#  ('사망', '환자'): 78,
#  ('세계', '개발'): 22,
#  ('세계', '기부'): 3,
#  ('세계', '기업'): 9,
#  ('세계', '대구'): 2,
#  ('세계', '한국'): 60,
#  ('신규', '개발'): 4,
#  ('신규', '검사'): 11,
#  ('신규', '국내'): 386,
#  ('신규', '기업'): 8,
#  ('신규', '대구'): 116,
#  ('신규', '발생'): 699,
#  ('신규', '방역'): 26,
#  ('신규', '백신'): 2,
#  ('신규', '사망'): 103,
#  ('신규', '세계'): 19,
#  ('신규', '여파'): 22,
#  ('신규', '위기'): 8,
#  ('신규', '정부'): 17,
#  ('신규', '종합'): 235,
#  ('신규', '지역'): 595,
#  ('신규', '추가'): 66,
#  ('신규', '치료'): 6,
#  ('신규', '치료제'): 2,
#  ('신규', '피해'): 3,
#  ('신규', '한국'): 5,
#  ('신규', '해외'): 623,
#  ('신규', '환자'): 228,
#  ('여파', '검사'): 5,
#  ('여파', '기부'): 2,
#  ('여파', '기업'): 30,
#  ('여파', '대구'): 12,
#  ('여파', '백신'): 2,
#  ('여파', '세계'): 50,
#  ('여파', '위기'): 18,
#  ('여파', '정부'): 7,
#  ('여파', '피해'): 5,
#  ('여파', '한국'): 33,
#  ('여파', '해외'): 20,
#  ('위기', '개발'): 4,
#  ('위기', '기부'): 46,
#  ('위기', '기업'): 65,
#  ('위기', '대구'): 23,
#  ('위기', '세계'): 34,
#  ('위기', '정부'): 37,
#  ('위기', '한국'): 15,
#  ('정부', '개발'): 117,
#  ('정부', '기부'): 12,
#  ('정부', '기업'): 15,
#  ('정부', '대구'): 12,
#  ('정부', '세계'): 20,
#  ('정부', '한국'): 32,
#  ('종합', '개발'): 22,
#  ('종합', '검사'): 84,
#  ('종합', '국내'): 89,
#  ('종합', '기부'): 10,
#  ('종합', '기업'): 15,
#  ('종합', '대구'): 71,
#  ('종합', '백신'): 41,
#  ('종합', '세계'): 45,
#  ('종합', '여파'): 46,
#  ('종합', '위기'): 49,
#  ('종합', '정부'): 57,
#  ('종합', '지역'): 84,
#  ('종합', '추가'): 131,
#  ('종합', '치료제'): 30,
#  ('종합', '피해'): 23,
#  ('종합', '한국'): 36,
#  ('종합', '해외'): 84,
#  ('종합', '환자'): 120,
#  ('지역', '개발'): 1,
#  ('지역', '검사'): 12,
#  ('지역', '기부'): 16,
#  ('지역', '기업'): 16,
#  ('지역', '대구'): 119,
#  ('지역', '백신'): 2,
#  ('지역', '세계'): 6,
#  ('지역', '여파'): 19,
#  ('지역', '위기'): 31,
#  ('지역', '정부'): 12,
#  ('지역', '추가'): 71,
#  ('지역', '피해'): 53,
#  ('지역', '한국'): 7,
#  ('지역', '해외'): 429,
#  ('지원', '감염'): 32,
#  ('지원', '개발'): 90,
#  ('지원', '검사'): 26,
#  ('지원', '국내'): 19,
#  ('지원', '기부'): 59,
#  ('지원', '기업'): 215,
#  ('지원', '대구'): 80,
#  ('지원', '대응'): 274,
#  ('지원', '발생'): 6,
#  ('지원', '방역'): 165,
#  ('지원', '백신'): 79,
#  ('지원', '사망'): 4,
#  ('지원', '세계'): 16,
#  ('지원', '신규'): 5,
#  ('지원', '여파'): 29,
#  ('지원', '위기'): 159,
#  ('지원', '정부'): 253,
#  ('지원', '종합'): 52,
#  ('지원', '지역'): 144,
#  ('지원', '추가'): 130,
#  ('지원', '치료'): 8,
#  ('지원', '치료제'): 80,
#  ('지원', '피해'): 757,
#  ('지원', '한국'): 34,
#  ('지원', '해외'): 23,
#  ('지원', '확산'): 67,
#  ('지원', '환자'): 17,
#  ('추가', '개발'): 5,
#  ('추가', '검사'): 47,
#  ('추가', '기부'): 5,
#  ('추가', '기업'): 7,
#  ('추가', '대구'): 80,
#  ('추가', '백신'): 11,
#  ('추가', '세계'): 4,
#  ('추가', '여파'): 11,
#  ('추가', '위기'): 5,
#  ('추가', '정부'): 31,
#  ('추가', '피해'): 56,
#  ('추가', '한국'): 6,
#  ('추가', '해외'): 87,
#  ('치료', '개발'): 15,
#  ('치료', '검사'): 2,
#  ('치료', '국내'): 23,
#  ('치료', '기부'): 5,
#  ('치료', '기업'): 1,
#  ('치료', '대구'): 19,
#  ('치료', '방역'): 32,
#  ('치료', '백신'): 6,
#  ('치료', '사망'): 24,
#  ('치료', '세계'): 9,
#  ('치료', '정부'): 20,
#  ('치료', '종합'): 19,
#  ('치료', '지역'): 8,
#  ('치료', '추가'): 15,
#  ('치료', '치료제'): 45,
#  ('치료', '한국'): 1,
#  ('치료', '해외'): 1,
#  ('치료', '환자'): 144,
#  ('치료제', '개발'): 688,
#  ('치료제', '기부'): 6,
#  ('치료제', '기업'): 14,
#  ('치료제', '대구'): 1,
#  ('치료제', '백신'): 500,
#  ('치료제', '세계'): 13,
#  ('치료제', '정부'): 153,
#  ('치료제', '추가'): 4,
#  ('치료제', '한국'): 19,
#  ('치료제', '해외'): 4,
#  ('피해', '개발'): 1,
#  ('피해', '기부'): 97,
#  ('피해', '기업'): 240,
#  ('피해', '대구'): 46,
#  ('피해', '세계'): 12,
#  ('피해', '위기'): 11,
#  ('피해', '정부'): 42,
#  ('피해', '한국'): 9,
#  ('피해', '해외'): 3,
#  ('한국', '기부'): 22,
#  ('한국', '기업'): 15,
#  ('해외', '개발'): 7,
#  ('해외', '기부'): 17,
#  ('해외', '기업'): 27,
#  ('해외', '대구'): 27,
#  ('해외', '세계'): 8,
#  ('해외', '위기'): 5,
#  ('해외', '정부'): 19,
#  ('해외', '한국'): 28,
#  ('확산', '감염'): 256,
#  ('확산', '개발'): 30,
#  ('확산', '검사'): 25,
#  ('확산', '국내'): 71,
#  ('확산', '기부'): 89,
#  ('확산', '기업'): 21,
#  ('확산', '대구'): 33,
#  ('확산', '대응'): 73,
#  ('확산', '발생'): 65,
#  ('확산', '방역'): 149,
#  ('확산', '백신'): 7,
#  ('확산', '사망'): 16,
#  ('확산', '세계'): 108,
#  ('확산', '신규'): 172,
#  ('확산', '여파'): 66,
#  ('확산', '위기'): 31,
#  ('확산', '정부'): 71,
#  ('확산', '종합'): 171,
#  ('확산', '지역'): 153,
#  ('확산', '추가'): 43,
#  ('확산', '치료'): 4,
#  ('확산', '치료제'): 6,
#  ('확산', '피해'): 22,
#  ('확산', '한국'): 56,
#  ('확산', '해외'): 33,
#  ('확산', '환자'): 42,
#  ('확진', '감염'): 986,
#  ('확진', '개발'): 15,
#  ('확진', '검사'): 292,
#  ('확진', '국내'): 1156,
#  ('확진', '극복'): 4,
#  ('확진', '기부'): 10,
#  ('확진', '기업'): 4,
#  ('확진', '대구'): 423,
#  ('확진', '대응'): 53,
#  ('확진', '발생'): 2321,
#  ('확진', '방역'): 212,
#  ('확진', '백신'): 14,
#  ('확진', '사망'): 340,
#  ('확진', '세계'): 364,
#  ('확진', '신규'): 3174,
#  ('확진', '여파'): 40,
#  ('확진', '위기'): 44,
#  ('확진', '정부'): 64,
#  ('확진', '종합'): 805,
#  ('확진', '지역'): 852,
#  ('확진', '지원'): 40,
#  ('확진', '추가'): 1366,
#  ('확진', '치료'): 87,
#  ('확진', '치료제'): 2,
#  ('확진', '피해'): 28,
#  ('확진', '한국'): 96,
#  ('확진', '해외'): 1044,
#  ('확진', '확산'): 394,
#  ('확진', '환자'): 544,
#  ('환자', '개발'): 13,
#  ('환자', '검사'): 53,
#  ('환자', '국내'): 267,
#  ('환자', '기부'): 1,
#  ('환자', '대구'): 76,
#  ('환자', '백신'): 7,
#  ('환자', '세계'): 27,
#  ('환자', '여파'): 3,
#  ('환자', '위기'): 10,
#  ('환자', '정부'): 26,
#  ('환자', '지역'): 60,
#  ('환자', '추가'): 143,
#  ('환자', '치료제'): 38,
#  ('환자', '한국'): 35,
#  ('환자', '해외'): 62}

# %%
## 3-1. 어휘 동시 출현 빈도를 데이터프레임으로 변환 #############################
df_co_occurrence = pd.DataFrame.from_dict(co_occurrence, orient='index', columns=['빈도'])
df_co_occurrence[:30].sort_index()
df_co_occurrence[:30].sort_values(by='빈도', ascending=False)
# Out:
#             빈도
# (확진, 발생)  2321
# (확진, 추가)  1366
# (확진, 국내)  1156
# (확진, 감염)   986
# (확진, 지역)   852
# (확진, 종합)   805
# (지원, 피해)   757
# (확진, 환자)   544
# (발생, 국내)   523
# (확진, 확산)   394
# (확진, 세계)   364
# (발생, 추가)   356
# (발생, 환자)   340
# (확진, 검사)   292
# (지원, 정부)   253
# (대응, 정부)   204
# (감염, 종합)   180
# (확산, 종합)   171
# (환자, 추가)   143
# (대응, 방역)   121
# (감염, 추가)   120
# (국내, 추가)   111
# (종합, 검사)    84
# (발생, 대구)    83
# (추가, 대구)    80
# (환자, 대구)    76
# (종합, 정부)    57
# (대응, 종합)    56
# (감염, 검사)    49
# (발생, 검사)    32

# %%
## 3-2. 어휘 동시 출현 빈도를 데이터프레임으로 변환 : 멀티 인덱스로 변환 #############################
copy_df_co_occurrence = df_co_occurrence.copy()
copy_df_co_occurrence.index = pd.MultiIndex.from_tuples(copy_df_co_occurrence.index)
copy_df_co_occurrence
# Out:
#            빈도
# 확진  환자    544
#     발생   2321
#     국내   1156
#     추가   1366
# 발생  국내    523
# ...       ...
# 사망  치료제     1
# 지역  백신      2
# 치료제 대구      1
# 백신  피해      1
# 치료  해외      1
#
# [411 rows x 1 columns]

# %%
df_co_occurrence['빈도'][0]
# Out:
# 544

# %%
list_df_co_occurrence = []

for idx in range(len(df_co_occurrence)):
    #index를 중심으로 계속 중첩해서 list에 넣는다 
    list_df_co_occurrence.append([df_co_occurrence.index[idx][0],
                                  df_co_occurrence.index[idx][1],
                                  df_co_occurrence['빈도'][idx]])

list_df_co_occurrence

df2_co_occurrence = pd.DataFrame(list_df_co_occurrence, columns=['term1', 'term2', 'freq'])
df2_co_occurrence
df2_co_occurrence.sort_values(by=['freq'], ascending=False)
final_co_occurrence = df2_co_occurrence.sort_values(by=['freq'], ascending=False)
final_co_occurrence
# Out:
#     term1 term2  freq
# 160    확진    신규  3174
# 1      확진    발생  2321
# 3      확진    추가  1366
# 2      확진    국내  1156
# 70     확진    해외  1044
# ..    ...   ...   ...
# 371    검사    위기     1
# 372    치료    기업     1
# 390    발생    개발     1
# 389    치료    한국     1
# 410    치료    해외     1
#
# [411 rows x 3 columns]

# %%
## 차트

import numpy as np
import networkx as nx
import operator

## 단어 네트워크 Graph
G=nx.Graph()


## 페이지 랭크에 따라 두 노드 사이 연관성 결정(단어쌍의 연관성)
## 연결 중심성으로 계산한 척도에 따라 노드의 크기 결정(단어 등장 빈도수)
for i in range(len(final_co_occurrence)):
    G.add_edge(final_co_occurrence['term1'][i], 
               final_co_occurrence['term2'][i], 
               weight=int(final_co_occurrence['freq'][i]))

# Compute centralities for nodes.
# The degree centrality values are normalized by dividing by the maximum possible degree in a simple graph n-1 where n is the number of nodes in G.
dgr = nx.degree_centrality(G)          ## 연결 중심성
btw = nx.betweenness_centrality(G)     ## 매개 중심성
cls = nx.closeness_centrality(G)       ## 근접 중심성

# itemgetter(0): key 또는 itemgetter(1): value로 sort key, reverse=True (descending order)
sorted_dgr = sorted(dgr.items(), key=operator.itemgetter(1), reverse=True)
sorted_btw = sorted(btw.items(), key=operator.itemgetter(1), reverse=True)
sorted_cls = sorted(cls.items(), key=operator.itemgetter(1), reverse=True)

print("** degree **")
for x in range(20):
    print(sorted_dgr[x])

print("** betweenness **")
for x in range(20):
    print(sorted_btw[x])

print("** closeness **")
for x in range(20):
    print(sorted_cls[x])


for idx in range(len(sorted_cls)):
    G.add_node(sorted_cls[idx][0], nodesize=sorted_cls[idx][1])
#     G.add_node(sorted_btw[idx][0], nodesize=sorted_btw[idx][1])
#     G.add_node(sorted_dgr[idx][0], nodesize=sorted_dgr[idx][1])
    
for idx in range(len(sorted_cls)):
    G.add_weighted_edges_from([(final_co_occurrence['term1'][idx],
                               final_co_occurrence['term2'][idx],
                               #int(final_co_occurrence['freq'][idx]))
                               int(sorted_cls[idx][1]))
                              ])
# Out:
# ** degree **
# ('확진', 1.0)
# ('추가', 1.0)
# ('확산', 1.0)
# ('종합', 1.0)
# ('대응', 1.0)
# ('정부', 1.0)
# ('지원', 1.0)
# ('감염', 1.0)
# ('세계', 1.0)
# ('방역', 1.0)
# ('한국', 1.0)
# ('해외', 1.0)
# ('국내', 0.9655172413793103)
# ('검사', 0.9655172413793103)
# ('대구', 0.9655172413793103)
# ('지역', 0.9655172413793103)
# ('신규', 0.9655172413793103)
# ('발생', 0.9310344827586207)
# ('기업', 0.9310344827586207)
# ('개발', 0.9310344827586207)
# ** betweenness **
# ('확진', 0.0025507172915611555)
# ('추가', 0.0025507172915611555)
# ('확산', 0.0025507172915611555)
# ('종합', 0.0025507172915611555)
# ('대응', 0.0025507172915611555)
# ('정부', 0.0025507172915611555)
# ('지원', 0.0025507172915611555)
# ('감염', 0.0025507172915611555)
# ('세계', 0.0025507172915611555)
# ('방역', 0.0025507172915611555)
# ('한국', 0.0025507172915611555)
# ('해외', 0.0025507172915611555)
# ('대구', 0.0022360688857797446)
# ('국내', 0.002127892989426508)
# ('신규', 0.002127892989426508)
# ('검사', 0.0020042604643161505)
# ('지역', 0.0020042604643161505)
# ('발생', 0.0018094552695109558)
# ('환자', 0.0017045888715411098)
# ('기업', 0.0015528766942345866)
# ** closeness **
# ('확진', 1.0)
# ('추가', 1.0)
# ('확산', 1.0)
# ('종합', 1.0)
# ('대응', 1.0)
# ('정부', 1.0)
# ('지원', 1.0)
# ('감염', 1.0)
# ('세계', 1.0)
# ('방역', 1.0)
# ('한국', 1.0)
# ('해외', 1.0)
# ('국내', 0.9666666666666667)
# ('검사', 0.9666666666666667)
# ('대구', 0.9666666666666667)
# ('지역', 0.9666666666666667)
# ('신규', 0.9666666666666667)
# ('발생', 0.9354838709677419)
# ('기업', 0.9354838709677419)
# ('개발', 0.9354838709677419)

# %%
sorted_cls[0][1]
final_co_occurrence['term1'][0]
final_co_occurrence['term2'][0]
# Out:
# '환자'

# %%
sorted_cls
# Out:
# [('확진', 1.0),
#  ('추가', 1.0),
#  ('확산', 1.0),
#  ('종합', 1.0),
#  ('대응', 1.0),
#  ('정부', 1.0),
#  ('지원', 1.0),
#  ('감염', 1.0),
#  ('세계', 1.0),
#  ('방역', 1.0),
#  ('한국', 1.0),
#  ('해외', 1.0),
#  ('국내', 0.9666666666666667),
#  ('검사', 0.9666666666666667),
#  ('대구', 0.9666666666666667),
#  ('지역', 0.9666666666666667),
#  ('신규', 0.9666666666666667),
#  ('발생', 0.9354838709677419),
#  ('기업', 0.9354838709677419),
#  ('개발', 0.9354838709677419),
#  ('환자', 0.90625),
#  ('피해', 0.90625),
#  ('위기', 0.90625),
#  ('치료', 0.90625),
#  ('백신', 0.90625),
#  ('극복', 0.90625),
#  ('여파', 0.8787878787878788),
#  ('기부', 0.8787878787878788),
#  ('치료제', 0.8529411764705882),
#  ('사망', 0.8285714285714286)]

# %%
## 노드 크기 결정
size = [G.nodes[node]['nodesize'] * 1000 for node in G]

options = {
    'node_color': '#CDEAFF',
    'edge_color': '#aaa',
    'width': 1,
    'with_labels': True,
    'font_weight': 'regular',
}

## 폰트 설정을 위한 font_manager import
import matplotlib.font_manager as fm
import matplotlib.pyplot as plt

## 폰트 설정
# plt.rcParams['font.family'] ='Malgun Gothic'
plt.rc('font', family='NanumGothic') ## 글꼴

## 
nx.draw(G, 
        node_size=size,
        #pos=nx.spring_layout(G, k=5.2, iterations=100),
        pos=nx.spring_layout(G, k=10, iterations=100),
        #pos=nx.spring_layout(G),
        #pos=nx.shell_layout(G),
        **options,
        # font_family='Malgun Gothic',
        font_family='NanumGothic',
        #alpha=0.8,
        #cmap=plt.cm.cmap_d,
       )

ax = plt.gca()
# ax.collections[0].set_edgecolor('#eee')
plt.show()
plt.savefig('network.svg')
print('<<table_1 이미지 저장 완료 >>')
# Out:
# <<table_1 이미지 저장 완료 >>
